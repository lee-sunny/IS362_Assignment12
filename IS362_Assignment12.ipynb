# %% [markdown]
# # IS 362 - Week 12 Assignment
# Sunah Lee
#
# # Web APIs
# The New York Times web site provides a rich set of APIs, as described here: http://developer.nytimes.com/docs You’ll need to start by signing up for an API key.
# Your task is to choose one of the New York Times APIs, construct an interface in Python to read in the JSON data, and transform it into a pandas DataFrame.
#
# I chose movie reviews API in the New York Times website
# One of the example calls provided is: https://api.nytimes.com/svc/movies/v2/reviews/search.json?query=godfather&api-key=yourkey
#
# ## Use personal API key to read in the JSON data

# %%
import pandas as pd
from pandas.io.json import json_normalize
import json, requests

api_key = 'qq2BDfrhPT0G4yNBmuMZIAwDNt9teWJb'
url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?'

myrequest = url + '&api-key=' + api_key
movie_review = json.loads(requests.get(myrequest).text) 
movie_review
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'has_more': True,
#  'num_results': 20,
#  'results': [{'display_title': 'The Half of It',
#    'mpaa_rating': '',
#    'critics_pick': 1,
#    'byline': 'Kyle Turner',
#    'headline': '‘The Half of It’ Review: Being Yourself (and That Person, Too)',
#    'summary_short': 'In this comedy from Alice Wu, love letters reveal everything about a person, except their identity.',
#    'publication_date': '2020-05-01',
#    'opening_date': '2020-05-01',
#    'date_updated': '2020-05-01 07:06:03',
#    'link': {'type': 'article',
#     'url': 'http://www.nytimes.com/2020/05/01/movies/the-half-of-it-review.html',
#     'suggested_link_text': 'Read the New York Times Review of The Half of It'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
# ...

# %% [markdown]
# ## Transform data into pandas DataFrame

# %%
transform = pd.json_normalize(movie_review['results'])
transform
# Out:
#                                display_title mpaa_rating  critics_pick  \
# 0                             The Half of It                         1
# 1                        All Day and a Night           R             0
# 2                     Until the Birds Return                         1
# 3                                Our Mothers                         0
# 4                                   Deerskin                         0
# 5                           The Infiltrators                         0
# 6        Capital in the Twenty-First Century                         0
# 7                                    Liberté                         0
# 8                               The Wretched                         0
# 9                                  Closeness                         0
# 10                                      Bull                         0
# 11                                  15 Years                         0
# ...

# %% [markdown]
# ## Organize and display data

# %%
df = transform[['display_title', 'mpaa_rating','opening_date', 'byline']]
df
# Out:
#                                display_title mpaa_rating opening_date  \
# 0                             The Half of It               2020-05-01
# 1                        All Day and a Night           R   2020-05-01
# 2                     Until the Birds Return               2020-04-28
# 3                                Our Mothers                     None
# 4                                   Deerskin                     None
# 5                           The Infiltrators               2020-06-02
# 6        Capital in the Twenty-First Century               2020-04-03
# 7                                    Liberté                     None
# 8                               The Wretched               2020-05-01
# 9                                  Closeness                     None
# 10                                      Bull               2020-05-01
# 11                                  15 Years                     None
# ...
